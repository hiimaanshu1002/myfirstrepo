# %%
import numpy as np

# %%
#Q1
arr = np.random.randint(1,100,(5,5))

# %%
print(arr)
# Out:
# [[25  3 32 46 91]
#  [80 97 82 99 42]
#  [30 83  5 32  3]
#  [38 57 69 30 78]
#  [93 68 14 92 40]]

# %%
arr.shape
# Out:
# (5, 5)

# %%
5//2
# Out:
# 2

# %%
#a)
print(arr[2][2])
# Out:
# 5

# %%
#b)
print(arr.mean(axis = 1))
# Out:
# [39.4 80.  30.6 54.4 61.4]

# %%
#c)
arr1 = arr[arr > arr.mean()]

# %%
print(arr1)
# Out:
# [91 80 97 82 99 83 57 69 78 93 68 92]

# %%
def spiral_order(matrix):
    result = []
    bottom = matrix.shape[0] - 1
    right = matrix.shape[1] - 1
    top = 0
    left = 0

    while top <= bottom and left <= right:
        for i in range(left,right+1):
            result.append(int(matrix[top][i]))
        top+=1

        for i in range(top,bottom+1):
            result.append(int(matrix[i][right]))
        right-=1

        for i in range(right,left-1,-1):
            result.append(int(matrix[bottom][i]))
        bottom-=1

        for i in range(bottom,top-1,-1):
            result.append(int(matrix[i][left]))
        left+=1
    return result

# %%
np.ndarray
# Out:
# numpy.ndarray

# %%
spiarr = spiral_order(arr)

# %%
spiarr
# Out:
# [25,
#  3,
#  32,
#  46,
#  91,
#  42,
#  3,
#  78,
#  40,
#  92,
#  14,
#  68,
#  93,
#  38,
#  30,
#  80,
#  97,
#  82,
#  99,
#  32,
#  30,
#  69,
#  57,
#  83,
#  5]

# %%
import pandas as pd

# %%
#Q2
df = pd.read_csv('Downloads/videogamesales.csv')

# %%
df
# Out:
#                                              Name Platform    Year     Genre  \
# 0                                       Asteroids     2600  1980.0   Shooter
# 1                                 Missile Command     2600  1980.0   Shooter
# 2                                         Kaboom!     2600  1980.0      Misc
# 3                                        Defender     2600  1980.0      Misc
# 4                                          Boxing     2600  1980.0  Fighting
# ...                                           ...      ...     ...       ...
# 16578           WRC: FIA World Rally Championship     X360     NaN    Racing
# 16579           WRC: FIA World Rally Championship       PC     NaN    Racing
# 16580  Writing and Speaking Beautiful Japanese DS       DS     NaN      Misc
# 16581  Yu-Gi-Oh! 5D's Wheelie Breakers (JP sales)      Wii     NaN    Racing
# 16582                    Zero: Tsukihami no Kamen      Wii     NaN    Action
#
# ...

# %%
df['Global_Sales'] = df['NA_Sales'] + df['EU_Sales'] + df['JP_Sales'] + df['Other_Sales']

# %%
#a)
df.sort_values('Global_Sales', ascending = False)
# Out:
#                                                    Name Platform    Year  \
# 6109                                         Wii Sports      Wii  2006.0
# 122                                   Super Mario Bros.      NES  1985.0
# 8315                                     Mario Kart Wii      Wii  2008.0
# 9743                                  Wii Sports Resort      Wii  2009.0
# 705                            Pokemon Red/Pokemon Blue       GB  1996.0
# ...                                                 ...      ...     ...
# 15723                Dragon Quest X: All in One Package     WiiU  2015.0
# 15727                                  Durarara!! Relay      PSV  2015.0
# 15734                                 Fallout Anthology       PC  2015.0
# 15737               Farming Simulator 15 Expansion Pack       PC  2015.0
# 9650   SCORE International Baja 1000: The Official Game      PS2  2008.0
#
#               Genre               Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#b)
plt.bar(data=df, x='Genre', height='Global_Sales')
plt.title('Total Sales by Genre')
plt.xticks(rotation = 45)
plt.show()

# %%
filtered_games = df[df['Name'].str.contains('Grand Theft Auto')].copy()

# %%
filtered_games
# Out:
#                                                     Name Platform    Year  \
# 999                                     Grand Theft Auto       PS  1997.0
# 1290                                  Grand Theft Auto 2       PS  1998.0
# 1469      Grand Theft Auto: Mission Pack #1, London 1969       PS  1998.0
# 2323                                Grand Theft Auto III      PS2  2001.0
# 2805                         Grand Theft Auto: Vice City      PS2  2002.0
# 3563                                Grand Theft Auto III       PC  2002.0
# 3639   Rockstar Games Double Pack: Grand Theft Auto I...       XB  2003.0
# 3688   Rockstar Games Double Pack: Grand Theft Auto I...      PS2  2003.0
# 4356                         Grand Theft Auto: Vice City       PC  2003.0
# 4405                       Grand Theft Auto: San Andreas      PS2  2004.0
# 4704                                    Grand Theft Auto      GBA  2004.0
# 5173              Grand Theft Auto: Liberty City Stories      PSP  2005.0
# ...

# %%
filtered_games['EU_JP'] = filtered_games['EU_Sales'] + filtered_games['JP_Sales']

# %%
filtered_games[['Name','Platform','Year','EU_JP']]
# Out:
#                                                     Name Platform    Year  \
# 999                                     Grand Theft Auto       PS  1997.0
# 1290                                  Grand Theft Auto 2       PS  1998.0
# 1469      Grand Theft Auto: Mission Pack #1, London 1969       PS  1998.0
# 2323                                Grand Theft Auto III      PS2  2001.0
# 2805                         Grand Theft Auto: Vice City      PS2  2002.0
# 3563                                Grand Theft Auto III       PC  2002.0
# 3639   Rockstar Games Double Pack: Grand Theft Auto I...       XB  2003.0
# 3688   Rockstar Games Double Pack: Grand Theft Auto I...      PS2  2003.0
# 4356                         Grand Theft Auto: Vice City       PC  2003.0
# 4405                       Grand Theft Auto: San Andreas      PS2  2004.0
# 4704                                    Grand Theft Auto      GBA  2004.0
# 5173              Grand Theft Auto: Liberty City Stories      PSP  2005.0
# ...

# %%
plt.pie(data = filtered_games, x = 'Global_Sales', labels = 'Name',radius =2, rotatelabels = 30)
plt.show()
